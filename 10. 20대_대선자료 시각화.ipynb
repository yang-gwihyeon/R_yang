# %%
# 데이터 불러오기
election <- read.csv("../R_yang/election_2022.csv")

# %%
head(election)
# Out:
#   광역시도   시군구   선거인수 투표수 이재명 윤석열 심상정
# 1 서울특별시 종로구   129968   100629  46130  49172 3115
# 2 서울특별시 중구     111448    84998  38244  42906 2310
# 3 서울특별시 용산구   199077   152068  60063  85047 4374
# 4 서울특별시 성동구   252087   197240  84411 103880 5365
# 5 서울특별시 광진구   303582   235471 109922 113733 7072
# 6 서울특별시 동대문구 300928   232106 108171 112890 6416

# %%
election$광역시도
# Out:
#   [1] 서울특별시     서울특별시     서울특별시     서울특별시     서울특별시
#   [6] 서울특별시     서울특별시     서울특별시     서울특별시     서울특별시
#  [11] 서울특별시     서울특별시     서울특별시     서울특별시     서울특별시
#  [16] 서울특별시     서울특별시     서울특별시     서울특별시     서울특별시
#  [21] 서울특별시     서울특별시     서울특별시     서울특별시     서울특별시
#  [26] 부산광역시     부산광역시     부산광역시     부산광역시     부산광역시
#  [31] 부산광역시     부산광역시     부산광역시     부산광역시     부산광역시
#  [36] 부산광역시     부산광역시     부산광역시     부산광역시     부산광역시
#  [41] 부산광역시     대구광역시     대구광역시     대구광역시     대구광역시
#  [46] 대구광역시     대구광역시     대구광역시     대구광역시     인천광역시
#  [51] 인천광역시     인천광역시     인천광역시     인천광역시     인천광역시
#  [56] 인천광역시     인천광역시     인천광역시     인천광역시     광주광역시
#  [61] 광주광역시     광주광역시     광주광역시     광주광역시     대전광역시
#  [66] 대전광역시     대전광역시     대전광역시     대전광역시     울산광역시
#  [71] 울산광역시     울산광역시     울산광역시     울산광역시     세종특별자치시
#  [76] 경기도         경기도         경기도         경기도         경기도
#  [81] 경기도         경기도         경기도         경기도         경기도
#  [86] 경기도         경기도         경기도         경기도         경기도
# ...

# %%
aaa <- aggregate(투표수 ~ 광역시도, election, sum)
aaa

ratio <- aaa / sum(aaa) * 100


par(family = 'AppleGothic')
pie3D(aaa,
    main = "영업실적 파이차트",
    explode = 0.05,
    labelcex = 0.8
   )
# Out:
#    광역시도       투표수
# 1  강원도         1015458
# 2  경기도         8518854
# 3  경상남도       2146882
# 4  경상북도       1774284
# 5  광주광역시      985492
# 6  대구광역시     1611512
# 7  대전광역시      945308
# 8  부산광역시     2200224
# 9  서울특별시     6501831
# 10 세종특별자치시  231832
# 11 울산광역시      735461
# 12 인천광역시     1883504
# 13 전라남도       1282168
# 14 전라북도       1235212
# 15 제주특별자치도  409649
# 16 충청남도       1324660
# 17 충청북도        962333
# Error in FUN(X[[i]], ...): only defined on a data frame with all numeric variables
# Traceback:
#
# 1. Summary.data.frame(structure(list(광역시도 = structure(1:17, .Label = c("강원도",
#  . "경기도", "경상남도", "경상북도", "광주광역시",
#  . "대구광역시", "대전광역시", "부산광역시", "서울특별시",
#  . "세종특별자치시", "울산광역시", "인천광역시",
#  . "전라남도", "전라북도", "제주특별자치도", "충청남도",
#  . "충청북도"), class = "factor"), 투표수 = c(1015458L, 8518854L,
#  . 2146882L, 1774284L, 985492L, 1611512L, 945308L, 2200224L, 6501831L,
#  . 231832L, 735461L, 1883504L, 1282168L, 1235212L, 409649L, 1324660L,
# ...

# %%
# electionSum = 이재명 + 윤석열 + 심상정

# %%
library(dplyr)

# %%
aaa <- aggregate(투표수 ~ 광역시도, election, sum)

# %%
head(election)
# Out:
#   광역시도   시군구   선거인수 투표수 이재명 윤석열 심상정
# 1 서울특별시 종로구   129968   100629  46130  49172 3115
# 2 서울특별시 중구     111448    84998  38244  42906 2310
# 3 서울특별시 용산구   199077   152068  60063  85047 4374
# 4 서울특별시 성동구   252087   197240  84411 103880 5365
# 5 서울특별시 광진구   303582   235471 109922 113733 7072
# 6 서울특별시 동대문구 300928   232106 108171 112890 6416

# %%
#더해서 추가히가기
election$electionsum <- apply(election[,5:7], 1 ,sum)
head(election)
# Out:
#   광역시도   시군구   선거인수 투표수 이재명 윤석열 심상정 electionsum
# 1 서울특별시 종로구   129968   100629  46130  49172 3115    98417
# 2 서울특별시 중구     111448    84998  38244  42906 2310    83460
# 3 서울특별시 용산구   199077   152068  60063  85047 4374   149484
# 4 서울특별시 성동구   252087   197240  84411 103880 5365   193656
# 5 서울특별시 광진구   303582   235471 109922 113733 7072   230727
# 6 서울특별시 동대문구 300928   232106 108171 112890 6416   227477

# %%
# electionRatio <- 투표수 대비 electionSum의 퍼센트 구해서 넣기
election$electionRatio <- election$electionsum / election$투표수 * 100
election$electionRatio
# Out:
#   [1] 97.80183 98.19055 98.30076 98.18292 97.98531 98.00565 97.93722 98.12141
#   [9] 97.82901 98.09985 98.09303 98.08788 98.12411 98.17850 98.27725 98.04303
#  [17] 98.08552 97.88455 98.23015 98.15955 97.56436 98.61234 98.59180 98.40630
#  [25] 98.27301 97.35114 97.62990 97.47665 97.62190 97.54063 97.79883 97.81340
#  [33] 97.54818 98.02593 97.69850 97.45270 97.64764 97.92988 97.91605 97.93335
#  [41] 97.30495 97.77302 97.72696 97.41010 97.39899 97.82520 98.26327 97.77710
#  [49] 97.62775 97.68988 97.88357 97.63684 98.36948 97.85593 97.88149 97.83766
#  [57] 97.96899 97.56153 96.02334 98.49886 98.49334 98.46695 98.40660 98.14610
#  [65] 97.49517 97.84325 97.85550 98.05564 97.41343 97.31440 97.49462 96.45348
#  [73] 97.13850 97.14376 98.18317 97.92530 97.82221 97.86921 98.28604 98.23112
#  [81] 98.14565 98.69751 97.95207 98.08736 98.48497 98.08854 98.31831 97.60367
#  [89] 97.68896 97.43099 97.74627 97.83102 98.31627 98.40968 98.44814 98.38728
# ...

# %%
arrange(election,desc(electionRatio))[1,]
arrange(election,desc(electionRatio))[nrow(election),]
# Out:
# Error: 객체 'electionRatio'를 찾을 수 없습니다
# Traceback:
#
# 1. arrange(election, desc(electionRatio))
# 2. arrange.data.frame(election, desc(electionRatio))
# 3. as.data.frame(arrange(tbl_df(.data), ..., .by_group = .by_group))
# 4. arrange(tbl_df(.data), ..., .by_group = .by_group)
# 5. arrange.tbl_df(tbl_df(.data), ..., .by_group = .by_group)
# 6. arrange_impl(.data, dots, environment())

# %%
# 2) subset
subset(election, electionRatio == max(election$electionRatio))
subset(election, electionRatio == min(election$electionRatio))
# Out:
# Error in eval(e, x, parent.frame()): 객체 'electionRatio'를 찾을 수 없습니다
# Traceback:
#
# 1. subset(election, electionRatio == max(election$electionRatio))
# 2. subset.data.frame(election, electionRatio == max(election$electionRatio))
# 3. eval(e, x, parent.frame())
# 4. eval(e, x, parent.frame())

# %%
# election_2022_job1.csv
head(election)
# Out:
#   광역시도   시군구   선거인수 투표수 이재명 윤석열 심상정 지역
# 1 서울특별시 종로구   129968   100629  46130  49172 3115   수도권
# 2 서울특별시 중구     111448    84998  38244  42906 2310   수도권
# 3 서울특별시 용산구   199077   152068  60063  85047 4374   수도권
# 4 서울특별시 성동구   252087   197240  84411 103880 5365   수도권
# 5 서울특별시 광진구   303582   235471 109922 113733 7072   수도권
# 6 서울특별시 동대문구 300928   232106 108171 112890 6416   수도권

# %%
write.csv(election,"../R_yang/election02.csv", row.names = F)

# %%
library(stringr)

# %%
library(plotrix)

# %%
# 각 후보(윤석열, 이재명, 심상정)의 광역도시별 득표율을 3D Pie Chart로 표현하기
# 단 득표율이 3% 미만인 광역시도는 광역시도 명만 출력하고 퍼센트는 출력하지 않는다. / 퍼센트 단위는 소수 한자리
aaa <- aggregate(투표수 ~ 광역시도:심상정, election, sum)
head(aaa)
sales <- c(210, 110, 400, 550, 600, 130)
week <- c("월","화","수","목","금","토")
ratio <- sales / sum(sales) * 100
#label <- paste(week,"\n",ratio,"%")

par(family = 'AppleGothic')
options(warn = -1)
pie3D(aaa,
    main = "영업실적 파이차트",
    labels = label,
    explode = 0.05,
    labelcex = 0.8,
    radius = 1
   )
# Out:
#   광역시도 심상정 투표수
# 1 경상북도 109     6653
# 2 경상북도 208    12337
# 3 경상북도 216    18239
# 4 전라남도 219    21744
# 5 전라북도 222    16230
# 6 전라북도 230    19879
# Error in pie3D(aaa, main = "영업실적 파이차트", labels = label, : pie3D: x values must be positive numbers
# Traceback:
#
# 1. pie3D(aaa, main = "영업실적 파이차트", labels = label,
#  .     explode = 0.05, labelcex = 0.8, radius = 1)
# 2. stop("pie3D: x values must be positive numbers")

# %%
sim <- aggregate(심상정 ~ 광역시도, election, sum)
vote <- aggregate(투표수 ~ 광역시도, election, sum)
sum(sim$심상정)
aaa <- (sim$심상정 / sum(sim$심상정)) *100
aaa
bbb <- cbind(vote)
bbb
# Out:
# [1] 797452
#  [1]  3.1388723 25.2194489  6.5948797  4.1536042  1.8640620  3.9038086
#  [7]  3.1907877  5.9616127 22.6125209  0.8502079  2.6700040  6.5022095
# [13]  2.0413768  2.4391437  1.7051810  3.9863214  3.1659586
#    광역시도       투표수
# 1  강원도         1015458
# 2  경기도         8518854
# 3  경상남도       2146882
# 4  경상북도       1774284
# 5  광주광역시      985492
# 6  대구광역시     1611512
# 7  대전광역시      945308
# 8  부산광역시     2200224
# 9  서울특별시     6501831
# 10 세종특별자치시  231832
# 11 울산광역시      735461
# 12 인천광역시     1883504
# 13 전라남도       1282168
# 14 전라북도       1235212
# 15 제주특별자치도  409649
# 16 충청남도       1324660
# 17 충청북도        962333

# %%
#label <- paste(week,"\n",ratio,"%")

par(family = 'AppleGothic')
week <- bbb$광역시도
options(warn = -1)
label <- paste(week,"\n",round(aaa,1),"%")
label2 <- paste(week)
pie3D(aaa,
    main = "심상정 파이차트",
    explode = 0.05,
    labelcex = 0.8,
    radius = 1.1,
    labels = ifelse(aaa>=3,label,label2),
   )
# Out:
# Plot with title “심상정 파이차트”

# %%
#label <- paste(week,"\n",ratio,"%")

sim <- aggregate(심상정 ~ 광역시도, election, sum)
vote <- aggregate(투표수 ~ 광역시도, election, sum)
sum(sim$심상정)
aaa <- (sim$심상정 / sum(sim$심상정)) *100
aaa
bbb <- cbind(vote)

par(family = 'AppleGothic')
week <- bbb$광역시도
options(warn = -1)
label <- paste(week,"\n",round(aaa,1),"%")
label2 <- paste(week)
pie3D(aaa,
    main = "심상정 파이차트",
    explode = 0.05,
    labelcex = 0.8,
    radius = 1.1,
    labels = ifelse(aaa>=3,label,label2)
   )
# Out:
# [1] 797452
#  [1]  3.1388723 25.2194489  6.5948797  4.1536042  1.8640620  3.9038086
#  [7]  3.1907877  5.9616127 22.6125209  0.8502079  2.6700040  6.5022095
# [13]  2.0413768  2.4391437  1.7051810  3.9863214  3.1659586
# Plot with title “심상정 파이차트”

# %%
# 수도권(경기도, 서울, 인천)의 투표인구수의 퍼센트?

# %%
head(election)
# Out:
#   광역시도   시군구   선거인수 투표수 이재명 윤석열 심상정 지역
# 1 서울특별시 종로구   129968   100629  46130  49172 3115   수도권
# 2 서울특별시 중구     111448    84998  38244  42906 2310   수도권
# 3 서울특별시 용산구   199077   152068  60063  85047 4374   수도권
# 4 서울특별시 성동구   252087   197240  84411 103880 5365   수도권
# 5 서울특별시 광진구   303582   235471 109922 113733 7072   수도권
# 6 서울특별시 동대문구 300928   232106 108171 112890 6416   수도권

# %%
sum(election$투표수)
# Out:
# [1] 33764664

# %%
a <- subset(election, 광역시도 == "서울특별시" | 광역시도 == "인천광역시" | 광역시도 == "경기도")

# %%
paste(round((sum(a$투표수)/sum(election$투표수))*100,2),"%")
# Out:
# [1] "50.06 %"

# %%
#윤석열 후보의 서울득표 top 5

# %%
eee <- arrange(subset(election, 광역시도 == "서울특별시"),desc(윤석열))

# %%
bbb <- eee[1:5,c(2,6)][2]
bbbb <- eee[1:5,c(2,6)]
ccc <- eee[-(1:5),c(2,6)][2]

# %%
bbb
bbbb
# Out:
#   윤석열
# 1 255166
# 2 235897
# 3 181510
# 4 179472
# 5 163340
#   시군구 윤석열
# 1 송파구 255166
# 2 강남구 235897
# 3 강서구 181510
# 4 서초구 179472
# 5 노원구 163340

# %%
ccc
# Out:
#    윤석열
# 6  160593
# 7  151944
# 8  149780
# 9  140666
# 10 135733
# 11 135044
# 12 134846
# 13 127129
# 14 124327
# 15 118201
# 16 113733
# 17 112890
# 18 103880
# 19  99780
# 20  98924
# 21  86540
# 22  85047
# 23  69227
# 24  49172
# 25  42906

# %%
eee <- sum(ccc)

# %%
eee
# Out:
# [1] 2240362

# %%
par(family = 'AppleGothic')
ttt <- '기타'

# %%
bbbb2 <- c(ttt, eee)
bbbb <- rbind(bbbb, bbbb2)
bbbb
# Out:
#   시군구 윤석열
# 1 송파구 255166
# 2 강남구 235897
# 3 강서구 181510
# 4 서초구 179472
# 5 노원구 163340
# 6 NA     2240362

# %%
head(election)
library(dplyr)
library(stringr)
# Out:
#   광역시도   시군구   선거인수 투표수 이재명 윤석열 심상정 지역
# 1 서울특별시 종로구   129968   100629  46130  49172 3115   수도권
# 2 서울특별시 중구     111448    84998  38244  42906 2310   수도권
# 3 서울특별시 용산구   199077   152068  60063  85047 4374   수도권
# 4 서울특별시 성동구   252087   197240  84411 103880 5365   수도권
# 5 서울특별시 광진구   303582   235471 109922 113733 7072   수도권
# 6 서울특별시 동대문구 300928   232106 108171 112890 6416   수도권

# %%
### 윤석열 후보의 서울 top 5 득표율 표시하고 나머지 지역은 기타로 합치기
#서울특별시 데이타만 발췌하기

election_seoul <- election[election$광역시도=="서울특별시" , ]
arrange(election_seoul, desc(윤석열))
election_seoul_윤석열 <- arrange(election_seoul, desc(윤석열))[,c(2,6)]
head(election_seoul_윤석열)
# Out:
#    광역시도   시군구   선거인수 투표수 이재명 윤석열 심상정 지역
# 1  서울특별시 송파구   565840   453536 180490 255166 10652  수도권
# 2  서울특별시 강남구   451970   354778 106865 235897  7020  수도권
# 3  서울특별시 강서구   504185   390247 190000 181510 11100  수도권
# 4  서울특별시 서초구   344756   277878  88686 179472  5864  수도권
# 5  서울특별시 노원구   441879   349297 169275 163340 10021  수도권
# 6  서울특별시 강동구   397634   313203 139172 160593  8029  수도권
# 7  서울특별시 관악구   446161   340773 169284 151944 11245  수도권
# 8  서울특별시 양천구   378710   301379 138586 149780  7821  수도권
# 9  서울특별시 은평구   417391   317971 161510 140666  9715  수도권
# 10 서울특별시 동작구   342248   271510 122914 135733  7866  수도권
# 11 서울특별시 성북구   375880   292187 142702 135044  8952  수도권
# 12 서울특별시 영등포구 334361   263581 116443 134846  7627  수도권
# 13 서울특별시 구로구   348156   272920 133027 127129  7539  수도권
# 14 서울특별시 마포구   324091   256218 117916 124327  9308  수도권
# 15 서울특별시 중랑구   347108   260862 130381 118201  6899  수도권
# 16 서울특별시 광진구   303582   235471 109922 113733  7072  수도권
# ...

# %%
election_seoul_윤석열_ratio <-
    round(c(election_seoul_윤석열[1:5,2], sum(election_seoul_윤석열[-c(1:5),2]))/ 
            sum(election_seoul_윤석열$윤석열) * 100,2)

election_seoul_윤석열_ratio

#라벨만들기

election_seoul_윤석열_label <- c(as.character(election_seoul_윤석열$시군구[1:5]),"기타")
election_seoul_윤석열_label
# Out:
# [1]  7.84  7.25  5.58  5.51  5.02 68.81
# [1] "송파구" "강남구" "강서구" "서초구" "노원구" "기타"

# %%
sung3 <- election_seoul_윤석열_ratio

par(family = 'AppleGothic')

week <- election_seoul_윤석열_label
options(warn = -1)
label <- paste(week,"\n",sung3,"%")
pie3D(sung3,
    main = "서울시 성북구의 후보별 득표율",
    labelcex = 1,
    radius = 1.0,
    labels = label,
    col = rainbow(6)
     )
# Out:
# Plot with title “서울시 성북구의 후보별 득표율”

# %%
#서울시 성북구의 후보별 득표율

# %%
sung <- election[election$시군구 == "성북구" , ]
sung
# Out:
#   광역시도   시군구 선거인수 투표수 이재명 윤석열 심상정 지역
# 8 서울특별시 성북구 375880   292187 142702 135044 8952   수도권

# %%
sung <- election[election$시군구 == "성북구" , ]
sung
etc <- sung$투표수 - sum(sung$이재명,sung$윤석열,sung$심상정)
sung2 <- c(sung$이재명,sung$윤석열,sung$심상정,etc)
sung2
total <- sum(sung$이재명,sung$윤석열,sung$심상정,etc)
total
sung3 <- round((sung2/total)*100,2)
sung3
# Out:
#   광역시도   시군구 선거인수 투표수 이재명 윤석열 심상정 지역
# 8 서울특별시 성북구 375880   292187 142702 135044 8952   수도권
# [1] 142702 135044   8952   5489
# [1] 292187
# [1] 48.84 46.22  3.06  1.88

# %%
sung <- election[election$시군구 == "성북구" , ]
sung
etc <- sung$투표수 - sum(sung$이재명,sung$윤석열,sung$심상정)
sung2 <- c(sung$이재명,sung$윤석열,sung$심상정,etc)
sung2
total <- sum(sung$이재명,sung$윤석열,sung$심상정,etc)
total
sung3 <- round((sung2/total)*100,2)
sung3
par(family = 'AppleGothic')

week <- c("이재명","윤석열","심상정","기타")
options(warn = -1)
label <- paste(week,"\n",sung3,"%")
pie3D(sung3,
    main = "서울시 성북구의 후보별 득표율",
    labelcex = 1,
    radius = 1.0,
    labels = label,
    col = c("skyblue","red","yellow","grey")
     )
# Out:
#   광역시도   시군구 선거인수 투표수 이재명 윤석열 심상정 지역
# 8 서울특별시 성북구 375880   292187 142702 135044 8952   수도권
# [1] 142702 135044   8952   5489
# [1] 292187
# [1] 48.84 46.22  3.06  1.88
# Plot with title “서울시 성북구의 후보별 득표율”

# %%
pob_윤석열 <- subset(election, 시군구 =="성북구")
pob_윤석열
# Out:
#   광역시도   시군구 선거인수 투표수 이재명 윤석열 심상정 지역
# 8 서울특별시 성북구 375880   292187 142702 135044 8952   수도권

# %%
as.numeric(c(pob_윤석열[,5:7],pob_윤석열[,4] - sum(pob_윤석열[5:7])))
# Out:
# [1] 142702 135044   8952   5489

# %% [markdown]
# ## 투표수가 가장많은 4지역(광역시도)의 후보별 득표수 차이를 막대그래프 시각화

# %%
# 1. 투표수가 가장 많은 4지역 뽑기 2.득표수 보여주기

# %%
library(dplyr)
library(stringr)
#four <- aggregate(투표수 ~ , election, sum)
#arrange(four, desc(투표수))
ffff <- arrange(aggregate(cbind(투표수,이재명,윤석열,심상정) ~ 광역시도, election, sum),desc(투표수))[1:4,3:5]
fff <- t(ffff)
str(ffff)
str(fff)
barplot(ffff,
       beside=T,
       )

#arrange(election, desc(투표수))[,]


#4개 뽑아냄
#four <- arrange(aggregate(cbind(colnames(election)) ~ 광역시도, election, sum), desc(투표수))[1:4,1]
#fourCha <- as.character(four)



#a <- election[election$광역도시 == fourCha , ]
#a
#election_seoul_윤석열 <- arrange(election_seoul, desc(윤석열))[,c(2,6)]
# Out:
# 'data.frame':	4 obs. of  3 variables:
#  $ 이재명: int  4297931 2944981 831896 794130
#  $ 윤석열: int  3859666 3255747 1270072 1237346
#  $ 심상정: int  201113 180324 47541 52591
#  int [1:3, 1:4] 4297931 3859666 201113 2944981 3255747 180324 831896 1270072 47541 794130 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:3] "이재명" "윤석열" "심상정"
#   ..$ : chr [1:4] "1" "2" "3" "4"
# Error in barplot.default(ffff, beside = T, ): 'height' must be a vector or a matrix
# Traceback:
#
# 1. barplot(ffff, beside = T, )
# 2. barplot.default(ffff, beside = T, )
# 3. stop("'height' must be a vector or a matrix")

# %%
colnames(election)[c(4,7)]
# Out:
# [1] "투표수" "심상정"

# %%
four4 <- arrange(aggregate(cbind(이재명,윤석열,심상정,투표수) ~ 광역시도, election, sum),desc(투표수))[1:4,2:4]
rownames(four4) <- c("경기도","서울특별시","부산광역시","경상남도")
four4
# Out:
#            이재명  윤석열  심상정
# 경기도     4297931 3859666 201113
# 서울특별시 2944981 3255747 180324
# 부산광역시  831896 1270072  47541
# 경상남도    794130 1237346  52591

# %%
as.matrix(four4[1,])
# Out:
#        이재명  윤석열  심상정
# 경기도 4297931 3859666 201113

# %%
par(family = "AppleGothic")

barplot(four,

       )
# Out:
# Error in barplot.default(four, ): 'height' must be a vector or a matrix
# Traceback:
#
# 1. barplot(four, )
# 2. barplot.default(four, )
# 3. stop("'height' must be a vector or a matrix")

# %%
        beside = T, # 누적부분 해체
      main = "성별 학력별 빈도수",
       xlab = "학력별",
       ylab = "빈도수",
       col = c('orange','yellow'),
        border = c('orange','yellow'),
        legend.text = T,
        ylim = c(0, 6),
# Out:
# Error in parse(text = x, srcfile = src): <text>:1:19: 예기치 않은 ','입니다
# 1:         beside = T,
#                       ^
# Traceback:

# %% [markdown]
# ---
# ## 투표수가 높은 시군구의 후보별 득표수를 막대그래프로 시각화

# %%
five <- arrange(election,desc(투표수))[1:5,5:7]
t(five)
five[1,5]
#a <- matrix(as.integer(c(five[1:5,7],five[1:5,6],five[1:5,5])),3,5)
#a
# Out:
#        1      2      3      4      5
# 이재명 283324 285227 239179 180490 190000
# 윤석열 236055 224331 203075 255166 181510
# 심상정  12955  13249  10089  10652  11100
# NULL

# %%
barplot(a,
 ylim = c(0, 600000)
       )
# Out:
# Error in barplot.default(a, ylim = c(0, 600000)): 'height' must be a vector or a matrix
# Traceback:
#
# 1. barplot(a, ylim = c(0, 600000))
# 2. barplot.default(a, ylim = c(0, 600000))
# 3. stop("'height' must be a vector or a matrix")

# %%
par(family="AppleGothic")
options(warn=-1)
options(scipen=100)

a <- t(arrange(election,desc(투표수))[1:5,5:7])
str(a)
#colnames(a) <- c("경기도 화성시","경기도 부천시","경기도 남양주시","서울특별시 송파구","서울특별시 강서구")
barplot(a,
        col= c("sky blue","red","yellow"),
        main = "투표수 높은 지역의 후보별 투표수",
        ylim = c(0,600000),
        names = c("경기도 화성시","경기도 부천시","경기도 남양주시","서울특별시 송파구","서울특별시 강서구"),
        cex.names = 0.7,
        legend = T
       )
# Out:
#  int [1:3, 1:5] 283324 236055 12955 285227 224331 13249 239179 203075 10089 180490 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:3] "이재명" "윤석열" "심상정"
#   ..$ : chr [1:5] "1" "2" "3" "4" ...
# Plot with title “투표수 높은 지역의 후보별 투표수”

# %%
# Out:
#  int [1:3, 1:5] 283324 236055 12955 285227 224331 13249 239179 203075 10089 180490 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:3] "이재명" "윤석열" "심상정"
#   ..$ : chr [1:5] "1" "2" "3" "4" ...

# %%
head(election)
# Out:
#   광역시도   시군구   선거인수 투표수 이재명 윤석열 심상정 지역
# 1 서울특별시 종로구   129968   100629  46130  49172 3115   수도권
# 2 서울특별시 중구     111448    84998  38244  42906 2310   수도권
# 3 서울특별시 용산구   199077   152068  60063  85047 4374   수도권
# 4 서울특별시 성동구   252087   197240  84411 103880 5365   수도권
# 5 서울특별시 광진구   303582   235471 109922 113733 7072   수도권
# 6 서울특별시 동대문구 300928   232106 108171 112890 6416   수도권

# %%
election2 <- election[election$광역시도 == c("서울특별시","인천광역시","경기도"),]
sum(election2[5])/sum(election2[4])
election2[5]
# Out:
# [1] 0.4843705
#     이재명
# 1    46130
# 4    84411
# 7   130381
# 10  106546
# 13  100702
# 16  190000
# 19  116443
# 22   88686
# 25  139172
# 50   43942
# 53  111446
# 56  100532
# 59    5218
# 78   58024
# 81   80857
# 84   82650
# 87  103470
# 90   28495
# 93  167037
# 96   21072
# 99  239179
# 102 178462
# 105 157155
# 108  80188
# 111  56723
# 114  12013

# %%
par(family="AppleGothic")
수도권 <-c('서울특별시','인천광역시','경기도')
강원권 <-'강원도'
영남권 <- c('경상북도','경상남도','대구광역시','부산광역시','울산광역시')
충청권 <- c('충청북도','충청남도','세종특별자치시','대전광역시')
호남권 <- c('전라남도','전라북도','제주특별자치도','광주광역시')

election$지역 <- ifelse(election$광역시도 %in% 수도권,'수도권',
               ifelse(election$광역시도 %in% 강원권,'강원권',
                     ifelse(election$광역시도 %in% 영남권,'영남권',
                           ifelse(election$광역시도 %in% 충청권,'충청권','호남권'))))

head(election)

elec1 <- aggregate(cbind(선거인수,투표수,이재명,윤석열,심상정)~지역,election,sum)
head(elec1)
elec1$ratio <- round(elec1$투표수/elec1$선거인수*100,2)
elec1$이ratio <- round(elec1$이재명/elec1$투표수*100,2)
elec1$윤ratio <- round(elec1$윤석열/elec1$투표수*100,2)
elec1$심ratio <- round(elec1$심상정/elec1$투표수*100,2)
arrange(elec1,desc(ratio))
elec2 <- t(arrange(elec1,desc(ratio))[1:5,7:10])
colnames(elec2)=c('호남권','영남권','수도권','강원권','충청권')
이 <- elec2[2,]
윤 <- elec2[3,]
심 <- elec2[4,]
이
윤
심
총 <- cbind(이,윤,심)
str(이)
str(윤)
plot(이,
     type ="b",
     ylim=c(0,100),
     axes=F,
     ann=F,
     col="sky blue",
     lty=3
    )

legend(3,100,
      c("이재명후보","윤석열후보","심상정후보"),
      col=c("sky blue","red","yellow"),
      pch=c(21,3,4),
      lty=c(3,5,1)
      )
title(main="20대 대선 권역별 후보 득표율", col.main="blue")
title(xlab="권역", col.lab="blue")
title(ylab="투표율", col.lab="blue")
axis(1,at=1:5,lab=c('호남권','영남권','수도권','강원권','충청권'))
axis(2,ylim=c(0,100))
lines(윤,
      type="o",
      pch=3,
      col="red",
      lty=5
     )
lines(심,
      type="o",
      pch=4,
      col="yellow",
      lty=1
     )
# Out:
#   광역시도   시군구   선거인수 투표수 이재명 윤석열 심상정 지역   투표율
# 1 서울특별시 종로구   129968   100629  46130  49172 3115   수도권 0.7742598
# 2 서울특별시 중구     111448    84998  38244  42906 2310   수도권 0.7626696
# 3 서울특별시 용산구   199077   152068  60063  85047 4374   수도권 0.7638652
# 4 서울특별시 성동구   252087   197240  84411 103880 5365   수도권 0.7824283
# 5 서울특별시 광진구   303582   235471 109922 113733 7072   수도권 0.7756422
# 6 서울특별시 동대문구 300928   232106 108171 112890 6416   수도권 0.7713008
#   이재명오차 윤석열오차 심상정오차
# 1 1.988344   0.30464141 0.7255291
# 2 2.836000   1.91883480 0.3477110
# 3 8.332538   7.36695373 0.5063448
# 4 5.033914   4.10680187 0.3500365
# 5 1.148243   0.25978469 0.6333422
# 6 1.225862   0.07726056 0.3942543
#   지역   선거인수 투표수   이재명  윤석열  심상정
# 1 강원권  1333621  1015458  419644  544980  25031
# 2 수도권 21971908 16904189 8156232 7993973 433289
# 3 영남권 10993369  8468363 2686576 5382549 185678
# 4 충청권  4602633  3464133 1573443 1719055  89261
# 5 호남권  4887963  3912521 3154923  619883  64193
# ...

# %%
colnames(election)[3:7]
elec5 <- aggregate(cbind(선거인수,투표수,이재명,윤석열,심상정)~지역,election,sum)
elec2
# Out:
# [1] "선거인수" "투표수"   "이재명"   "윤석열"   "심상정"
#         호남권 영남권 수도권 강원권 충청권
# ratio   80.04  77.03  76.94  76.14  75.26
# 이ratio 80.64  31.72  48.25  41.33  45.42
# 윤ratio 15.84  63.56  47.29  53.67  49.62
# 심ratio  1.64   2.19   2.56   2.46   2.58

# %%
head(election)
aaab<- aggregate(cbind(광역시도,선거인수,투표수) ~ 광역시도, election, sum)
head(aaab)
aaab$투표율 <- aaab$투표수/aaab$선거인수
aaab
# Out:
#   광역시도   시군구   선거인수 투표수 이재명 윤석열 심상정 지역
# 1 서울특별시 종로구   129968   100629  46130  49172 3115   수도권
# 2 서울특별시 중구     111448    84998  38244  42906 2310   수도권
# 3 서울특별시 용산구   199077   152068  60063  85047 4374   수도권
# 4 서울특별시 성동구   252087   197240  84411 103880 5365   수도권
# 5 서울특별시 광진구   303582   235471 109922 113733 7072   수도권
# 6 서울특별시 동대문구 300928   232106 108171 112890 6416   수도권
#   광역시도   광역시도 선거인수 투표수
# 1 강원도     18        1333621 1015458
# 2 경기도     82       11106036 8518854
# 3 경상남도   66        2809907 2146882
# 4 경상북도   96        2273028 1774284
# 5 광주광역시 25        1209206  985492
# 6 대구광역시 48        2046714 1611512
#    광역시도       광역시도 선거인수 투표수  투표율
# 1  강원도          18       1333621 1015458 0.7614292
# 2  경기도          82      11106036 8518854 0.7670472
# 3  경상남도        66       2809907 2146882 0.7640402
# 4  경상북도        96       2273028 1774284 0.7805817
# 5  광주광역시      25       1209206  985492 0.8149910
# 6  대구광역시      48       2046714 1611512 0.7873655
# ...

# %%
election
# Out:
#     광역시도       시군구           선거인수 투표수 이재명 윤석열 심상정 지역
# 1   서울특별시     종로구           129968   100629  46130  49172  3115  수도권
# 2   서울특별시     중구             111448    84998  38244  42906  2310  수도권
# 3   서울특별시     용산구           199077   152068  60063  85047  4374  수도권
# 4   서울특별시     성동구           252087   197240  84411 103880  5365  수도권
# 5   서울특별시     광진구           303582   235471 109922 113733  7072  수도권
# 6   서울특별시     동대문구         300928   232106 108171 112890  6416  수도권
# 7   서울특별시     중랑구           347108   260862 130381 118201  6899  수도권
# 8   서울특별시     성북구           375880   292187 142702 135044  8952  수도권
# 9   서울특별시     강북구           268974   199448 103333  86540  5245  수도권
# 10  서울특별시     도봉구           281812   216036 106546  99780  5605  수도권
# 11  서울특별시     노원구           441879   349297 169275 163340 10021  수도권
# 12  서울특별시     은평구           417391   317971 161510 140666  9715  수도권
# 13  서울특별시     서대문구         269615   210460 100702  98924  6886  수도권
# ...

# %%
투표율
광역시도별
득표율

# %%
election$투표율 <- election$투표수 / election$선거인수

elect75 <- election[election$투표율>=0.75,]
head(elect75)
elect85 <- aggregate(cbind(시군구,선거인수,투표수,이재명,윤석열,심상정)~광역시도, elect75, sum)
elect75$이재명득표율 <- elect75$이재명 / elect75$투표수
elect75$윤석열득표율 <- elect75$윤석열 / elect75$투표수
qq <- elect75[elect75$이재명득표율 >= 0.5 ,]
pp <- elect75[elect75$윤석열득표율 >= 0.5 ,]
qq
qq2 <- aggregate(cbind(시군구,투표수)~광역시도, qq, sum)
qq2
pp
# Out:
#   광역시도   시군구   선거인수 투표수 이재명 윤석열 심상정 지역   투표율
# 1 서울특별시 종로구   129968   100629  46130  49172 3115   수도권 0.7742598
# 2 서울특별시 중구     111448    84998  38244  42906 2310   수도권 0.7626696
# 3 서울특별시 용산구   199077   152068  60063  85047 4374   수도권 0.7638652
# 4 서울특별시 성동구   252087   197240  84411 103880 5365   수도권 0.7824283
# 5 서울특별시 광진구   303582   235471 109922 113733 7072   수도권 0.7756422
# 6 서울특별시 동대문구 300928   232106 108171 112890 6416   수도권 0.7713008
#     광역시도       시군구         선거인수 투표수 이재명 윤석열 심상정 지역
# 12  서울특별시     은평구         417391   317971 161510 140666  9715  수도권
# 18  서울특별시     금천구         208786   157035  80208  69227  4278  수도권
# 60  광주광역시     동구            90678    73877  60669  11036  1063  호남권
# 61  광주광역시     서구           248147   202633 170357  26262  2961  호남권
# 62  광주광역시     남구           180643   148854 124572  19927  2073  호남권
# 63  광주광역시     북구           363088   295658 249976  36421  4550  호남권
# 64  광주광역시     광산구         326650   264470 224484  30865  4218  호남권
# ...

# %%
count(pp,광역시도)
# Out:
#    광역시도   n
# 1  강원도     14
# 2  경기도      6
# 3  경상남도   18
# 4  경상북도   22
# 5  대구광역시  8
# 6  대전광역시  1
# 7  부산광역시  8
# 8  서울특별시  8
# 9  울산광역시  3
# 10 인천광역시  3
# 11 충청남도    8
# 12 충청북도    7

# %%
election$이재명오차 <- abs(47.83-((election$이재명/election$투표수)*100))
election$윤석열오차 <- abs(48.56-((election$윤석열/election$투표수)*100))
election$심상정오차 <- abs(2.37-((election$심상정/election$투표수)*100))
#election
a <- election[ election$이재명오차<1&election$윤석열오차<1&election$심상정오차<1&election$이재명<election$윤석열, ]
head(a)
a$오차의합 <- (a$이재명오차 + a$윤석열오차 + a$심상정오차)
b <- arrange(a,(오차의합))
#a$오차합 <- a$이재명오차+a$윤석열오차+a$심상정오차
#a
#a$오차의합 <- election$이재명오차+election$윤석열오차+election$심상정오차
b
# Out:
#     광역시도   시군구       선거인수 투표수 이재명 윤석열 심상정 지역
# 51  인천광역시 동구          53909    40918  19195  19661 1196   수도권
# 52  인천광역시 미추홀구     356862   253347 119287 121122 6951   수도권
# 68  대전광역시 유성구       288686   231027 108701 111342 6492   충청권
# 69  대전광역시 대덕구       152905   115404  54119  55159 3141   충청권
# 137 충청북도   청주시흥덕구 223335   163683  76940  77952 4770   충청권
#     투표율    이재명오차 윤석열오차 심상정오차
# 51  0.7590198 0.9191050  0.5102419  0.5529190
# 52  0.7099299 0.7455664  0.7512634  0.3736678
# 68  0.8002709 0.7787895  0.3656331  0.4400612
# 69  0.7547431 0.9347451  0.7635631  0.3517427
# 137 0.7329035 0.8245077  0.9362394  0.5441695
#   광역시도   시군구       선거인수 투표수 이재명 윤석열 심상정 지역   투표율
# 1 대전광역시 유성구       288686   231027 108701 111342 6492   충청권 0.8002709
# 2 인천광역시 미추홀구     356862   253347 119287 121122 6951   수도권 0.7099299
# 3 인천광역시 동구          53909    40918  19195  19661 1196   수도권 0.7590198
# 4 대전광역시 대덕구       152905   115404  54119  55159 3141   충청권 0.7547431
# ...

# %%
election
# Out:
#     광역시도       시군구           선거인수 투표수 이재명 윤석열 심상정 지역
# 1   서울특별시     종로구           129968   100629  46130  49172  3115  수도권
# 2   서울특별시     중구             111448    84998  38244  42906  2310  수도권
# 3   서울특별시     용산구           199077   152068  60063  85047  4374  수도권
# 4   서울특별시     성동구           252087   197240  84411 103880  5365  수도권
# 5   서울특별시     광진구           303582   235471 109922 113733  7072  수도권
# 6   서울특별시     동대문구         300928   232106 108171 112890  6416  수도권
# 7   서울특별시     중랑구           347108   260862 130381 118201  6899  수도권
# 8   서울특별시     성북구           375880   292187 142702 135044  8952  수도권
# 9   서울특별시     강북구           268974   199448 103333  86540  5245  수도권
# 10  서울특별시     도봉구           281812   216036 106546  99780  5605  수도권
# 11  서울특별시     노원구           441879   349297 169275 163340 10021  수도권
# 12  서울특별시     은평구           417391   317971 161510 140666  9715  수도권
# 13  서울특별시     서대문구         269615   210460 100702  98924  6886  수도권
# ...

# %%
par(family = "AppleGothic")
options(warn = -1)
barplot(b$오차의합,
        main = "각 시군구별 실제 투표율과 가장 유사한 지역 Top 5",
        ylim = c(0,2.5),
        col = "darkblue",
        names = b$시군구,
        cex.names = 0.7
       )
# Out:
# Plot with title “각 시군구별 실제 투표율과 가장 유사한 지역 Top 5”
